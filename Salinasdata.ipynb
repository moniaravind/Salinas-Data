# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io as io

# %%
matFile=io.loadmat('/content/drive/MyDrive/Salinas.mat')

# %%
type(matFile)
# Out:
# dict

# %%
matFile.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'salinas'])

# %%
matFile['__header__']
# Out:
# b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri May 20 18:22:17 2011'

# %%
matFileContent_2=matFile['salinas']

# %%
type(matFileContent_2)
# Out:
# numpy.ndarray

# %%
matFileContent_2.shape
# Out:
# (512, 217, 224)

# %%
matFileContent_2[0,0,:]
# Out:
# array([ 290,  381,  585, 1041, 1316, 1397, 1319, 1462, 1643, 1683, 1656,
#        1670, 1584, 1643, 1659, 1619, 1723, 1785, 1805, 1822, 1809, 1790,
#        1786, 1770, 1779, 1737, 1706, 1709, 1699, 1663, 1702, 1682, 1715,
#        1682, 1603, 1615, 1746, 1784, 1607, 1757, 1918, 1961, 1197, 1786,
#        1967, 1894, 1888, 1839, 1549, 1646, 1759, 1798, 1753, 1736, 1768,
#        1736, 1468, 1347, 1257, 1304,  607,  647,  717,  930, 1254, 1357,
#        1508, 1507, 1510, 1499, 1499, 1475, 1455, 1411, 1381, 1366, 1297,
#        1181,  992,  501,  293,  405,  410,  577,  891,  984,  965, 1027,
#         988, 1030, 1079, 1110, 1110, 1073,  943,  882, 1032,  880,  970,
#        1014, 1004,  894,  783,  653,  491,  264,   25,    5,    6,    6,
#          10,   10,   28,   54,   73,  108,  205,  195,  192,  276,  451,
#         537,  613,  657,  679,  692,  687,  666,  608,  638,  639,  604,
#         618,  637,  616,  596,  593,  581,  566,  555,  542,  519,  503,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(np.arange(matFileContent_2.shape[2]),matFileContent_2[0,0,:])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[0,0,:])
plt.subplot(1,3,2)
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[100,100,:])
plt.subplot(1,3,3)
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[200,200,:])
plt.show()

# %%
plt.imshow(matFileContent_2[:,:,5],cmap='viridis') # default cmap is 'viridis'
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,5,1)
plt.imshow(matFileContent_2[:,:,10])
plt.subplot(2,5,2)
plt.imshow(matFileContent_2[:,:,15])
plt.subplot(2,5,3)
plt.imshow(matFileContent_2[:,:,20])
plt.subplot(2,5,4)
plt.imshow(matFileContent_2[:,:,25])
plt.subplot(2,5,5)
plt.imshow(matFileContent_2[:,:,30])
plt.subplot(2,5,6)
plt.imshow(matFileContent_2[:,:,35])
plt.subplot(2,5,7)
plt.imshow(matFileContent_2[:,:,40])
plt.subplot(2,5,8)
plt.imshow(matFileContent_2[:,:,45])
plt.subplot(2,5,9)
plt.imshow(matFileContent_2[:,:,50])
plt.subplot(2,5,10)
plt.imshow(matFileContent_2[:,:,55])
plt.show()

# %%
gtFile=io.loadmat('/content/drive/MyDrive/Salinas_gt.mat')

# %%
type(gtFile)
# Out:
# dict

# %%
gtFile.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'salinas_gt'])

# %%
gtFileContent_2=gtFile['salinas_gt']

# %%
type(gtFileContent_2)
# Out:
# numpy.ndarray

# %%
gtFileContent_2.shape
# Out:
# (512, 217)

# %%
gtFileContent_2[100,80],gtFileContent_2[350,200],gtFileContent_2[500,200]
# Out:
# (8, 0, 0)

# %%
plt.imshow(gtFileContent_2,cmap='plasma')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[100,80,:],label='class-'+str(gtFileContent_2[100,80]))
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[350,200,:],label='class-'+str(gtFileContent_2[350,200]))
plt.plot(np.arange(matFileContent_2.shape[2]),matFileContent_2[500,200,:],label='class-'+str(gtFileContent_2[500,200]))
plt.legend()
plt.show()
